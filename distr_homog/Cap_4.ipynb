# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
h = 0.5
r = np.arange(0.,2.,0.01)
n = len(r)

w = np.zeros(n)
dw = np.zeros(n)

# %%
import kernel

w = kernel.W(r,h)
dw = kernel.dW(r,h)
#print w

# %%
plt.plot(r,w,'o')

# %%
plt.plot(r,dw,'o')
